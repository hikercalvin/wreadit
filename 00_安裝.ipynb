# %%
# Install a pip package in the current Jupyter kernel
import sys

# %%
# !{sys.executable} -m pip install --upgrade pip

# %%
# !{sys.executable} -m pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (3.6.2)
# Requirement already satisfied: joblib in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from nltk) (1.0.1)
# Requirement already satisfied: regex in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from nltk) (2021.8.3)
# Requirement already satisfied: click in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from nltk) (8.0.1)
# Requirement already satisfied: tqdm in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from nltk) (4.62.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from click->nltk) (3.10.1)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from click->nltk) (0.4.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from importlib-metadata; python_version < "3.8"->click->nltk) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from importlib-metadata; python_version < "3.8"->click->nltk) (3.10.0.0)
# WARNING: You are using pip version 20.1.1; however, version 21.2.3 is available.
# You should consider upgrading via the 'C:\Users\aster\AppData\Local\Programs\Python\Python37\python.exe -m pip install --upgrade pip' command.

# %%
# !{sys.executable} -m pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (1.21.1)
# WARNING: You are using pip version 20.1.1; however, version 21.2.3 is available.
# You should consider upgrading via the 'C:\Users\aster\AppData\Local\Programs\Python\Python37\python.exe -m pip install --upgrade pip' command.

# %%
# !{sys.executable} -m pip install jieba==0.42.1
# Out:
# Requirement already satisfied: jieba==0.42.1 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (0.42.1)
# WARNING: You are using pip version 20.1.1; however, version 21.2.3 is available.
# You should consider upgrading via the 'C:\Users\aster\AppData\Local\Programs\Python\Python37\python.exe -m pip install --upgrade pip' command.

# %%
# !{sys.executable} -m pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (4.6.3)
# WARNING: You are using pip version 20.1.1; however, version 21.2.3 is available.
# You should consider upgrading via the 'C:\Users\aster\AppData\Local\Programs\Python\Python37\python.exe -m pip install --upgrade pip' command.

# %%
# !{sys.executable} -m pip install nbformat
# Out:
# Requirement already satisfied: nbformat in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (5.1.3)
# Requirement already satisfied: ipython-genutils in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from nbformat) (0.2.0)
# Requirement already satisfied: traitlets>=4.1 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from nbformat) (5.0.5)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from nbformat) (3.2.0)
# Requirement already satisfied: jupyter-core in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from nbformat) (4.7.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat) (3.10.1)
# Requirement already satisfied: setuptools in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat) (47.1.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat) (0.18.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat) (1.16.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from jupyter-core->nbformat) (301)
# Requirement already satisfied: zipp>=0.5 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat) (3.10.0.0)
# WARNING: You are using pip version 20.1.1; however, version 21.2.3 is available.
# You should consider upgrading via the 'C:\Users\aster\AppData\Local\Programs\Python\Python37\python.exe -m pip install --upgrade pip' command.

# %%
# !{sys.executable} -m pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (5.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from plotly) (1.16.0)
# WARNING: You are using pip version 20.1.1; however, version 21.2.3 is available.
# You should consider upgrading via the 'C:\Users\aster\AppData\Local\Programs\Python\Python37\python.exe -m pip install --upgrade pip' command.

# %%
# !{sys.executable} -m pip install scikit-learn
# Out:
# Collecting scikit-learn
# WARNING: You are using pip version 20.1.1; however, version 21.2.3 is available.
# You should consider upgrading via the 'C:\Users\aster\AppData\Local\Programs\Python\Python37\python.exe -m pip install --upgrade pip' command.
#   Using cached scikit_learn-0.24.2-cp37-cp37m-win_amd64.whl (6.8 MB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn) (1.21.1)
# Collecting scipy>=0.19.1
#   Using cached scipy-1.7.1-cp37-cp37m-win_amd64.whl (33.6 MB)
# Installing collected packages: scipy, scikit-learn
# Successfully installed scikit-learn-0.24.2 scipy-1.7.1

# %%
# !{sys.executable} -m pip install seaborn==0.9.0
# Out:
# Collecting seaborn==0.9.0
#   Using cached seaborn-0.9.0-py3-none-any.whl (208 kB)
# Collecting matplotlib>=1.4.3
#   Using cached matplotlib-3.4.2-cp37-cp37m-win_amd64.whl (7.1 MB)
# Requirement already satisfied: numpy>=1.9.3 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from seaborn==0.9.0) (1.21.1)
# Collecting pandas>=0.15.2
#   Downloading pandas-1.3.1-cp37-cp37m-win_amd64.whl (10.1 MB)
# Requirement already satisfied: scipy>=0.14.0 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from seaborn==0.9.0) (1.7.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (2.8.2)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.3.1-cp37-cp37m-win_amd64.whl (51 kB)
# Collecting pyparsing>=2.2.1
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting pillow>=6.2.0
#   Using cached Pillow-8.3.1-1-cp37-cp37m-win_amd64.whl (3.2 MB)
# Collecting pytz>=2017.3
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Requirement already satisfied: six>=1.5 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->seaborn==0.9.0) (1.16.0)
# Installing collected packages: kiwisolver, pyparsing, cycler, pillow, matplotlib, pytz, pandas, seaborn
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.4.2 pandas-1.3.1 pillow-8.3.1 pyparsing-2.4.7 pytz-2021.1 seaborn-0.9.0
# WARNING: You are using pip version 20.1.1; however, version 21.2.3 is available.
# You should consider upgrading via the 'C:\Users\aster\AppData\Local\Programs\Python\Python37\python.exe -m pip install --upgrade pip' command.

# %%
# !{sys.executable} -m pip install lifelines==0.25.4
# Out:
# Collecting lifelines==0.25.4
# WARNING: You are using pip version 20.1.1; however, version 21.2.3 is available.
# You should consider upgrading via the 'C:\Users\aster\AppData\Local\Programs\Python\Python37\python.exe -m pip install --upgrade pip' command.
#   Using cached lifelines-0.25.4-py3-none-any.whl (345 kB)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from lifelines==0.25.4) (1.21.1)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from lifelines==0.25.4) (1.7.1)
# Requirement already satisfied: pandas>=0.23.0 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from lifelines==0.25.4) (1.3.1)
# Collecting patsy>=0.5.0
#   Using cached patsy-0.5.1-py2.py3-none-any.whl (231 kB)
# Requirement already satisfied: matplotlib>=3.0 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from lifelines==0.25.4) (3.4.2)
# Processing c:\users\aster\appdata\local\pip\cache\wheels\ef\32\31\0e87227cd0ca1d99ad51fbe4b54c6fa02afccf7e483d045e04\autograd-1.3-py3-none-any.whl
# Processing c:\users\aster\appdata\local\pip\cache\wheels\9f\01\ee\1331593abb5725ff7d8c1333aee93a50a1c29d6ddda9665c9f\autograd_gamma-0.5.0-py3-none-any.whl
# Requirement already satisfied: pytz>=2017.3 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from pandas>=0.23.0->lifelines==0.25.4) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from pandas>=0.23.0->lifelines==0.25.4) (2.8.2)
# Requirement already satisfied: six in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from patsy>=0.5.0->lifelines==0.25.4) (1.16.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from matplotlib>=3.0->lifelines==0.25.4) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from matplotlib>=3.0->lifelines==0.25.4) (8.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from matplotlib>=3.0->lifelines==0.25.4) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from matplotlib>=3.0->lifelines==0.25.4) (2.4.7)
# Processing c:\users\aster\appdata\local\pip\cache\wheels\56\b0\fe\4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0\future-0.18.2-py3-none-any.whl
# Installing collected packages: patsy, future, autograd, autograd-gamma, lifelines
# Successfully installed autograd-1.3 autograd-gamma-0.5.0 future-0.18.2 lifelines-0.25.4 patsy-0.5.1

# %%
# !{sys.executable} -m pip install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.0.7-py2.py3-none-any.whl (243 kB)
# Collecting et-xmlfile
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.7
# WARNING: You are using pip version 20.1.1; however, version 21.2.3 is available.
# You should consider upgrading via the 'C:\Users\aster\AppData\Local\Programs\Python\Python37\python.exe -m pip install --upgrade pip' command.

# %%
# !{sys.executable} -m pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
# WARNING: You are using pip version 20.1.1; however, version 21.2.3 is available.
# You should consider upgrading via the 'C:\Users\aster\AppData\Local\Programs\Python\Python37\python.exe -m pip install --upgrade pip' command.
#   Using cached beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
# Collecting soupsieve>1.2; python_version >= "3.0"
#   Using cached soupsieve-2.2.1-py3-none-any.whl (33 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.9.3 soupsieve-2.2.1

# %%
# !{sys.executable} -m pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (1.3.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from pandas) (1.21.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\aster\appdata\local\programs\python\python37\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: You are using pip version 20.1.1; however, version 21.2.3 is available.
# You should consider upgrading via the 'C:\Users\aster\AppData\Local\Programs\Python\Python37\python.exe -m pip install --upgrade pip' command.
